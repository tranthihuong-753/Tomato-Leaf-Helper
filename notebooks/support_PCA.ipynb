# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import numpy as np

# Load HOG features từ file
hog_features = np.load("../results/hog_features.npy")

pca = PCA(n_components=441)
pca.fit(hog_features)
cumsum = np.cumsum(pca.explained_variance_ratio_)

plt.plot(cumsum)
plt.xlabel('Số thành phần PCA')
plt.ylabel('Tỉ lệ phương sai tích lũy')
plt.grid()
plt.show()

# %% [markdown]
# -> Giữ lại tầm 300 đặc trưng thì sẽ giữ được từ 90~95% thông tin
