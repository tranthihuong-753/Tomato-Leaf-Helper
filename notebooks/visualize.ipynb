# %% [markdown]
# Trực quan hóa dữ liệu trước khi huấn luyện mô hình với các biểu đồ
# 1. Vẽ biểu đồ phân phối lớp
# 2.

# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
import os
from collections import Counter

# %% [markdown]
# Gọi tập dữ liệu

# %%
X_train = np.load("../data/processed/train/x.npy")
y_train = np.load("../data/processed/train/y.npy")
X_valid = np.load("../data/processed/valid/x.npy")
y_valid = np.load("../data/processed/valid/y.npy")

# %%
class_names=[]
data_dir = "../data/train"
for label in os.listdir(data_dir):
    label_dir = os.path.join(data_dir, label) 
    if os.path.isdir(label_dir):
        class_names.append(label)

# %% [markdown]
# 1. Vẽ biểu đồ phân phối lớp

# %%
plt.figure()
data_dir = "../data/train"
counts = [len(os.listdir(os.path.join(data_dir, label))) for label in class_names]
sns.barplot(x=class_names, y=counts, palette="viridis")
plt.title("Phân phối lớp trong tập dữ liệu")
plt.xlabel("Lớp")
plt.ylabel("Số lượng mẫu")
plt.xticks(rotation=-90)  # Xoay nhãn lớp
plt.show()
# Out:
# C:\Users\dhhuo\AppData\Local\Temp\ipykernel_2940\1791780997.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=class_names, y=counts, palette="viridis")

# %% [markdown]
# Theo biểu đồ thì thấy dữ liệu bị mất cân bằng -> Thêm bản sao cho powdery_mildew

# %% [markdown]
# Biểu đồ với data mới

# %%
plt.figure()
data_dir = "../data/processed/train"
counts = [Counter(y_train)[i] for i in range(len(class_names))]
sns.barplot(x=class_names, y=counts, palette="viridis")
plt.title("Phân phối lớp trong tập dữ liệu")
plt.xlabel("Lớp")
plt.ylabel("Số lượng mẫu")
plt.xticks(rotation=-90)  # Xoay nhãn lớp
plt.show()
# Out:
# C:\Users\dhhuo\AppData\Local\Temp\ipykernel_21156\2994703549.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=class_names, y=counts, palette="viridis")
